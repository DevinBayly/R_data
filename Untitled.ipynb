# %%
my_data = read.table('gapminder-FiveYearData.csv',sep = ',',header = TRUE)

library('dplyr')
library('ggplot2')
library('gapminder')

# %%
my_data
# Out:
#                       country year        pop continent  lifeExp   gdpPercap
# 1                 Afghanistan 1952    8425333      Asia 28.80100    779.4453
# 2                 Afghanistan 1957    9240934      Asia 30.33200    820.8530
# 3                 Afghanistan 1962   10267083      Asia 31.99700    853.1007
# 4                 Afghanistan 1967   11537966      Asia 34.02000    836.1971
# 5                 Afghanistan 1972   13079460      Asia 36.08800    739.9811
# 6                 Afghanistan 1977   14880372      Asia 38.43800    786.1134
# 7                 Afghanistan 1982   12881816      Asia 39.85400    978.0114
# 8                 Afghanistan 1987   13867957      Asia 40.82200    852.3959
# 9                 Afghanistan 1992   16317921      Asia 41.67400    649.3414
# 10                Afghanistan 1997   22227415      Asia 41.76300    635.3414
# 11                Afghanistan 2002   25268405      Asia 42.12900    726.7341
# ...

# %%
dplyr::slice(my_data,)
